# %%
stack = [1,2,3,4]
stack.extend([5])

# %%
stack
# Out:
# [1, 2, 3, 4, 5]

# %%
def push(stack,a):
    stack.append(a)
    print(a)
def pop(stack):
    temp = stack[-1]
    del(stack[-1])
    print('the popped element is',temp)
def peek(stack):
    print('the element after popping is ',stack[-1])
stack = []
push(stack,4)
# Out:
# 4

# %%
pop(stack)
# Out:
# the popped element is 4

# %%
peek(stack)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 peek(stack)
#
# Cell In[3], line 9, in peek(stack)
#       8 def peek(stack):
# ----> 9     print('the element after popping is ',stack[-1])
#
# IndexError: list index out of range

# %%
print(stack)
# Out:
# []

# %%
class ArrayStack:
    def __init__(self,capacity):
        self.capacity=capacity
        self.stack=[None]*capacity
        self.top=-1

    def is_empty(self):
        return self.top==-1

    def is_full(self):
        return self.top==self.capacity-1

    def push(self,item):
        if self.is_full():
            raise Exception('stack overflow:cannot push to a full stack')
        self.top+=1
        self.stack[self.top]=item
        print(f'pushed{item} to stack')

    def pop(self):
        if self.is_empty():
            raise Exception('stack Underflow:Cannot open from a empty stack')
        item = self.stack[self.top]
        self.stack[self.top]=None
        self.top-=1
        return item
    def peek(self):
        if self.is_empty():
            raise Exception("stack is empty")
        return self.stack[self.top]
    def size(self):
        return self.top+1

stack = ArrayStack(3)

# %%
stack.push(10)
# Out:
# pushed10 to stack

# %%
stack.push(20)
# Out:
# pushed20 to stack

# %%
print(f"the top element is {stack.peek()}")
# Out:
# the top element is 20

# %%
print(f"popped:{stack.pop()}")
# Out:
# popped:20

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[17], line 25
#      23 #example
#      24 infix_expr = "(A + B) * C - (D / E )"
# ---> 25 postfix_expr = infix_to_postfix(infix_expr)
#      26 print(f"\ninifx:{infix_expr}")
#      27 print(f"\npostfix:{postfix_expr}")
#
# Cell In[17], line 14, in infix_to_postfix(expression)
#      12     while operator_stack and operator_stack[-1]!='(':
#      13         output.append(operator_stack.pop())
# ---> 14     operator_stack.pop()
#      15 else:
#      16     while (operator_stack and operator_stack[-1]!='(' and precedence.get(operator_stack[-1],0)>=precedence.get(token,0)):
#
# IndexError: pop from empty list

# %%
k = "(A + B) * C - (D / E )"
p= k.split()
print(p)
# Out:
# ['(A', '+', 'B)', '*', 'C', '-', '(D', '/', 'E', ')']
