# %%
from Tree import ExpressionTree
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from Tree import ExpressionTree
#
# File D:\3rd sem\DSA\Tree.py:244
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
#       5    "execution_count": 35,
#       6    "id": "ebb97717-94f1-4e04-8795-9038eee133b0",
#       7    "metadata": {},
#       8    "outputs": [],
#       9    "source": [
#      10     "from typing import Optional, Any,List\n",
#      11     "from collections import deque"
#      12    ]
#      13   },
#      14   {
#      15    "cell_type": "code",
#      16    "execution_count": 36,
#      17    "id": "55bb4813-5073-44ee-9bff-ec35851dd09c",
#      18    "metadata": {},
#      19    "outputs": [],
#      20    "source": [
#      21     "class TreeNode:\n",
#      22     "    def __init__(self,value: Any):\n",
# ...
